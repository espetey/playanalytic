# %%
# Scripts and doodles for getting Fortnite data.
# Refactor to save to db and make calls daily or weekly

# %%
# All Fortnite data and rights belong to Epic Games.
# Fortnite API - https://fortniteapi.com/

# Description of Fortnite Item Shop
# https://fortnite.gamepedia.com/Item_Shop

# V-Bucks/dollar exchange examples (~$0.00999/V-Buck)
# 1000 V-Bucks :: $9.99 - https://www.microsoft.com/en-us/p/fortnite-1-000-v-bucks/c0f5ht9nv86p?activetab=pivot:overviewtab
# 2800 :: $24.99 - https://www.microsoft.com/en-us/p/fortnite-2-500-300-bonus-v-bucks/c4bpbtqg5c1b?activetab=pivot%3Aoverviewtab
# 13500 ::  $99.99 - https://www.microsoft.com/en-us/p/fortnite-1-000-v-bucks/c0f5ht9nv86p?activetab=pivot:overviewtab
# Battle Pass (season 8): 950V :: $9.45

# Interesting relationships and pricing structures
# real dollar value of items/demand/voting/occurrence frequency.

# %%
import requests as reqs

# %%
# all items
items = reqs.get("https://fortnite-public-api.theapinetwork.com/prod09/items/list")
# items.text prints transferable json
itemsJson = items.json()
# print(len(itemsJson))
# print(itemsJson[0])
# for item in itemsJson:
#     print(item["name"])

# big blast returns "Request URI too large" if you use all at once
# reqs.get("https://fortnite-public-api.theapinetwork.com/prod09/item/get?ids=c3a4196-e107207-a617cec-ef48916")
# originalUri = 'https://fortnite-public-api.theapinetwork.com/prod09/item/get?ids='
# uri = originalUri
# i = 1
# spam request takes a bit
# for item in itemsJson:
#     itemReq = 'https://fortnite-public-api.theapinetwork.com/prod09/item/get?ids={}'.format(item['identifier'])
#     itemDetail = reqs.get(itemReq)
#     print(itemDetail.text)
#     uri = uri + item["identifier"]
#     used in big request
#     if i < len(itemsJson):
#         uri = '{},'.format(uri)
#     uri = '{},'.format(uri)
#     if i % 20 == 0:
#         itemDetailList = requests.get(uri)
#         print(itemDetailList.text)
#         uri = originalUri
#     i = i + 1
    
# itemDetailList = requests.get(uri)
# print(itemDetailList.text)

# %%
# upcoming items: https://fortnite-public-api.theapinetwork.com/prod09/upcoming/get
# specific item: https://fortnite-public-api.theapinetwork.com/prod09/item/get?ids=61ea3e9-8438e42-f53d351-e53a5ce
# c3a4196-e107207-a617cec-ef48916
store = reqs.get("https://fortnite-public-api.theapinetwork.com/prod09/store/get?language=en")
# print(store.text)
# storeItems = store.json()["items"]
# print(storeItems[0])
# for item in storeItems:
#     print(item["name"])

# %%
item = reqs.get("https://fortnite-public-api.theapinetwork.com/prod09/item/get?ids=c3a4196-e107207-a617cec-ef48916")
itemJson = item.json()
print(itemJson)
# Out:
# {'identifier': 'c3a4196-e107207-a617cec-ef48916', 'name': 'Cuddle Team Leader', 'description': 'Hug it out.', 'cost': 2000, 'type': 'outfit', 'rarity': 'legendary', 'upcoming': 0, 'lastupdate': 1554300788, 'obtained': '2000', 'obtained_type': 'vbucks', 'todaystore': 0, 'images': {'transparent': 'https://fortnite-public-files.theapinetwork.com/outfit/0424531c5bc3bec418c53c7d8a8ff82f.png', 'background': 'https://fortnite-public-files.theapinetwork.com/image/c3a4196-e107207-a617cec-ef48916.png', 'information': 'https://fortnite-public-files.theapinetwork.com/image/c3a4196-e107207-a617cec-ef48916/item.png', 'featured': {'transparent': 'https://fortnite-public-files.theapinetwork.com/featured/c3a4196-e107207-a617cec-ef48916.png'}}, 'ratings': {'avgStars': 4.12, 'totalPoints': 2952, 'numberVotes': 717}, 'set': {'name': 'Royale Hearts', 'entries': [{'identifier': '44e5df6-dab72cc-03a5edd-8d9e9c9', 'name': 'Cuddle Bow', 'type': 'backpack', 'lastupdate': 1554300788}, {'identifier': 'c3a4196-e107207-a617cec-ef48916', 'name': 'Cuddle Team Leader', 'type': 'outfit', 'lastupdate': 1554300788}, {'identifier': 'b011489-6f30d0b-9fd7a02-7b5fca8', 'name': 'Love Ranger', 'type': 'outfit', 'lastupdate': 1554300788}, {'identifier': 'b0edd4b-4f6040a-9252575-5011292', 'name': 'Love Wings', 'type': 'backpack', 'lastupdate': 1554300788}, {'identifier': '28dad80-86e5460-8852035-883ed08', 'name': 'Bear Force One', 'type': 'glider', 'lastupdate': 1554300788}, {'identifier': 'b2d7b5e-6177c91-ab71229-eef47cf', 'name': 'Kiss Kiss', 'type': 'emote', 'lastupdate': 1554300788}, {'identifier': '6fc0875-a4f0477-55ac591-d71b0ae', 'name': 'Tat Axe', 'type': 'pickaxe', 'lastupdate': 1554300788}, {'identifier': '4ccce49-0febe05-5d64388-33d9500', 'name': 'True Love', 'type': 'emote', 'lastupdate': 1554300788}]}, 'bundle': {'entries': []}, 'occurrences': {'first': '10-02-18', 'last': '02-04-19', 'occurrences': 13, 'entries': [{'date': '02-04-19', 'cost': 2000, 'featured': 1}, {'date': '15-02-19', 'cost': 2000, 'featured': 0}, {'date': '27-11-18', 'cost': 2000, 'featured': 1}, {'date': '16-10-18', 'cost': 2000, 'featured': 1}, {'date': '09-09-18', 'cost': 2000, 'featured': 1}, {'date': '29-08-18', 'cost': 2000, 'featured': 1}, {'date': '25-07-18', 'cost': 2000, 'featured': 1}, {'date': '19-06-18', 'cost': 2000, 'featured': 1}, {'date': '17-05-18', 'cost': 2000, 'featured': 0}, {'date': '19-04-18', 'cost': 2000, 'featured': 0}, {'date': '11-03-18', 'cost': 2000, 'featured': 0}, {'date': '15-02-18', 'cost': 2000, 'featured': 0}, {'date': '10-02-18', 'cost': 2000, 'featured': 0}]}, 'youtube': None}

# %%
import json

# %%
# get highest-occurring items
# todo: significance of zero-occurring items? what probability they will show up in the future?
with open('./snapshots/041619/itemDetails.json') as json_file:
    data = json.load(json_file)
    sortedDetails = sorted(data['itemDetails'], key=lambda item: item['occurrences']['occurrences'], reverse=True)
    for item in sortedDetails:
        itemInfo = '{name}, {occr}, {rarity}, {cost}'.format(
            name=item['name'],
            occr=item['occurrences']['occurrences'],
            rarity=item['rarity'],
            cost=item['cost']
        )
        print(itemInfo)
# Out:
# Brite Bomber, 41, rare, 1200
# Munitions Expert, 34, rare, 1200
# Arctic Assassin, 31, rare, 1200
# Circuit Breaker, 30, rare, 1200
# Recon Specialist, 29, rare, 1200
# Special Forces, 28, rare, 1200
# Dazzle, 25, rare, 1200
# Trooper, 25, uncommon, 800
# Survival Specialist, 24, rare, 1200
# Whiplash, 24, uncommon, 800
# Desperado, 23, rare, 1200
# First strike Specialist, 23, rare, 1200
# Commando, 23, uncommon, 800
# Shadow Ops, 22, epic, 1500
# Absolute Zero, 22, rare, 1200
# Brawler, 21, rare, 1200
# Snorkel Ops, 21, rare, 1200
# Jungle Scout, 20, uncommon, 800
# Scarlet Defender, 20, uncommon, 800
# Merry Marauder, 19, epic, 1500
# Assault Trooper, 19, uncommon, 800
# Dominator, 19, uncommon, 800
# Hyperion, 18, rare, 1200
# Ginger Gunner, 17, epic, 1500
# Plunja, 17, rare, 800
# Spectral Axe, 17, rare, 800
# Nitelite, 17, uncommon, 800
# Wukong, 16, legendary, 2000
# Infiltrator, 16, rare, 1200
# Sash Sergeant, 16, rare, 1200
# Burnout, 15, epic, 1500
# Electro Shuffle, 15, epic, 800
# Recon Scout, 15, rare, 1200
# Prismatic, 15, rare, 800
# Highland Warrior, 14, epic, 1500
# Brilliant Striker, 14, rare, 1200
# Red-Nosed Raider, 14, rare, 1200
# Batsickle, 14, rare, 800
# Spectre, 14, rare, 800
# Liteshow, 14, uncommon, 800
# Cuddle Team Leader, 13, legendary, 2000
# Cloud Strike, 13, epic, 1200
# True Heart, 13, epic, 800
# Radiant Striker, 13, rare, 1200
# Zany, 13, rare, 500
# Devastator, 13, uncommon, 800
# Renegade, 13, uncommon, 800
# Ice Breaker, 13, uncommon, 500
# Raptor, 12, legendary, 2000
# Red Knight, 12, legendary, 2000
# Tomatohead, 12, epic, 1500
# Llama Bell, 12, epic, 800
# Pop Lock, 12, epic, 800
# Chromium, 12, rare, 1200
# Gum Drop, 12, rare, 800
# Dragon Axe, 12, rare, 800
# Glow Stick, 12, rare, 800
# Studded Axe, 12, rare, 800
# Flippin' Sexy, 12, rare, 500
# Infinite Dab, 12, rare, 500
# Crimson Scout, 12, uncommon, 800
# Highrise Assault Trooper, 12, uncommon, 800
# Nog Ops, 12, uncommon, 800
# Scorpion, 12, uncommon, 800
# Dark Vanguard, 11, legendary, 2000
# Love Ranger, 11, legendary, 2000
# Raven, 11, legendary, 2000
# Rapscallion, 11, epic, 1500
# Reanimated, 11, epic, 800
# Diecast, 11, rare, 1200
# Midnight Ops, 11, rare, 1200
# Cliffhanger, 11, rare, 800
# Wiggle, 11, rare, 500
# Pathfinder, 11, uncommon, 800
# Scout, 11, uncommon, 800
# Tower Recon Specialist, 11, uncommon, 800
# Lucky, 11, uncommon, 500
# Fate, 10, legendary, 2000
# Overtaker, 10, epic, 1500
# Whiteout, 10, epic, 1500
# Split Wing, 10, epic, 1200
# Bottom Feeder, 10, epic, 1500
# Pick Squeak, 10, epic, 1500
# Breakin', 10, epic, 800
# Star Power, 10, epic, 800
# Dynamo, 10, rare, 1200
# Libre, 10, rare, 800
# Empire Axe, 10, rare, 800
# Fated Frame, 10, rare, 800
# Persuader, 10, rare, 800
# Eagle, 10, rare, 500
# Twist, 10, rare, 500
# Tracker, 10, uncommon, 800
# Yuletide Ranger, 10, uncommon, 800
# Tactical Spade, 10, uncommon, 500
# Victory Lap, 10, uncommon, 500
# Rex, 9, legendary, 2000
# Brite Gunner, 9, epic, 1500
# Funk Ops, 9, epic, 1500
# Skull Trooper, 9, epic, 1500
# Steelsight, 9, epic, 1500
# Toxic Trooper, 9, epic, 1500
# Wreck Raider, 9, epic, 1500
# White Squall, 9, epic, 1200
# Squat Kick, 9, epic, 800
# Moniker, 9, rare, 1200
# Googly, 9, rare, 800
# Stage Dive, 9, rare, 800
# Starry Flight, 9, rare, 800
# Axeroni, 9, rare, 800
# Crimson Axe, 9, rare, 800
# Cutting Edge, 9, rare, 800
# Stop Axe, 9, rare, 800
# Laugh It Up, 9, rare, 500
# Make it Rain, 9, rare, 500
# Pumpernickel, 9, rare, 500
# Tactics Officer, 9, uncommon, 800
# Jolly Roger, 9, uncommon, 500
# Jubilation, 9, uncommon, 200
# Slow Clap, 9, uncommon, 200
# Omen, 8, legendary, 2000
# Ravage, 8, legendary, 2000
# Wild Card, 8, legendary, 2000
# Abstrakt, 8, epic, 1500
# Beef Boss, 8, epic, 1500
# Cloaked Star, 8, epic, 1500
# Maverick, 8, epic, 1500
# Reef Ranger, 8, epic, 1500
# Scoundrel, 8, epic, 1500
# Venturion, 8, epic, 1500
# Deep Space Lander, 8, epic, 1200
# Flying Saucer, 8, epic, 1200
# Rusty Rider, 8, epic, 1200
# Chomp Jr., 8, epic, 1500
# Oracle Axe, 8, epic, 1200
# Pink Flamingo, 8, epic, 1500
# Disco Fever, 8, epic, 800
# Smooth Moves, 8, epic, 800
# Aerial Threat, 8, rare, 1200
# Cipher, 8, rare, 1200
# Clinical Crosser, 8, rare, 1200
# Dynamic Dribbler, 8, rare, 1200
# Finesse Finisher, 8, rare, 1200
# Midfield Maestro, 8, rare, 1200
# Poised Playmaker, 8, rare, 1200
# Stalwart Sweeper, 8, rare, 1200
# Super Striker, 8, rare, 1200
# Sushi Master, 8, rare, 1200
# Feathered Flyer, 8, rare, 800
# Safecracker, 8, rare, 800
# Autocleave, 8, rare, 800
# Filet Axe, 8, rare, 800
# Iron Beak, 8, rare, 800
# Nite Owl, 8, rare, 800
# Vuvuzela, 8, rare, 800
# Kick Ups, 8, rare, 500
# Work It Out, 8, rare, 500
# Grill Sergeant, 8, uncommon, 800
# Dark Glyph, 8, uncommon, 500
# Goalbound, 8, uncommon, 500
# Warthog, 8, uncommon, 500
# Elite Cleat, 8, uncommon, 500
# Icicle, 8, uncommon, 500
# Patty Whacker, 8, uncommon, 500
# T-Pose, 8, uncommon, 200
# Waterworks, 8, uncommon, 200
# Battle Hound, 7, legendary, 2000
# Chomp Sr., 7, legendary, 2000
# Criterion, 7, legendary, 2000
# Hime, 7, legendary, 2000
# Musha, 7, legendary, 2000
# Oblivion, 7, legendary, 2000
# Power Chord, 7, legendary, 2000
# Tricera Ops, 7, legendary, 2000
# Vertex, 7, legendary, 2000
# Laser Chomp, 7, legendary, 1500
# Bandolier, 7, epic, 1500
# Blitz, 7, epic, 1500
# End Zone, 7, epic, 1500
# Gridiron, 7, epic, 1500
# Hazard Agent, 7, epic, 1500
# Interceptor, 7, epic, 1500
# Juke, 7, epic, 1500
# Nite Nite, 7, epic, 1500
# Noir, 7, epic, 1500
# Rush, 7, epic, 1500
# Shade, 7, epic, 1500
# Spike, 7, epic, 1500
# Strong Guard, 7, epic, 1500
# Ventura, 7, epic, 1500
# Orbital Shuttle, 7, epic, 1200
# Servo, 7, epic, 1200
# Terminus, 7, epic, 1200
# Viceroy Mark I, 7, epic, 1200
# Death Valley, 7, epic, 1500
# Renegade Roller, 7, epic, 1200
# Dance Therapy, 7, epic, 800
# Fresh, 7, epic, 800
# Intensity, 7, epic, 800
# Rock Out, 7, epic, 800
# Forerunner, 7, rare, 800
# Zephyr, 7, rare, 800
# Cat's Claw, 7, rare, 800
# Razor Edge, 7, rare, 800
# Electro Swing, 7, rare, 500
# Fancy Feet, 7, rare, 500
# Flippin' Incredible, 7, rare, 500
# Hand Signals, 7, rare, 500
# Tidy, 7, rare, 500
# Armadillo, 7, uncommon, 800
# Garrison, 7, uncommon, 800
# Glow Rider, 7, uncommon, 500
# Mainframe, 7, uncommon, 500
# Purrfect., 7, uncommon, 500
# Snow Squall, 7, uncommon, 500
# Caliper, 7, uncommon, 500
# Inverted Blade, 7, uncommon, 500
# Arachne, 6, legendary, 2000
# Leviathan, 6, legendary, 0
# Magnus, 6, legendary, 2000
# Moisty Merman, 6, legendary, 2000
# Shogun, 6, legendary, 2000
# Sky Stalker, 6, legendary, 2000
# Spider Knight, 6, legendary, 2000
# Frostwing, 6, legendary, 1500
# Royale Dragon, 6, legendary, 2000
# Archetype, 6, epic, 1500
# Bunny Brawler, 6, epic, 1500
# Peekaboo, 6, epic, 1500
# Plague, 6, epic, 1500
# Rabbit Raider, 6, epic, 1500
# Scourge, 6, epic, 1500
# Hatchling, 6, epic, 1200
# Magic Wings, 6, epic, 1200
# Pterodactyl, 6, epic, 1200
# Bitemark, 6, epic, 1200
# Jingu Bang, 6, epic, 1200
# Rainbow Smash, 6, epic, 1500
# Thunder Crash, 6, epic, 1200
# Airheart, 6, rare, 1200
# Chopper, 6, rare, 1200
# Dark Bomber, 6, rare, 1200
# Fortune, 6, rare, 1200
# Masked Fury, 6, rare, 1200
# Maximilian, 6, rare, 1200
# Waypoint, 6, rare, 1200
# Flappy Flyer, 6, rare, 800
# Flying Carp, 6, rare, 800
# Kabuto, 6, rare, 800
# Lamplight, 6, rare, 800
# Anarchy Axe, 6, rare, 800
# Forebearer, 6, rare, 800
# Harpoon Axe, 6, rare, 800
# Herald's Wand, 6, rare, 800
# Jawblade, 6, rare, 800
# Magnifying Axe, 6, rare, 800
# Propeller Axe, 6, rare, 800
# Silver Fang, 6, rare, 800
# Spellslinger, 6, rare, 800
# Tooth Pick, 6, rare, 800
# Upright Axe, 6, rare, 800
# Web Breaker, 6, rare, 800
# Living Large, 6, rare, 500
# Pure Salt, 6, rare, 500
# Rambunctious, 6, rare, 500
# Ranger, 6, uncommon, 800
# Striped Soldier, 6, uncommon, 800
# Whistle Warrior, 6, uncommon, 800
# Checker, 6, uncommon, 500
# Flying Fish, 6, uncommon, 500
# Hot Rod, 6, uncommon, 500
# Petunia, 6, uncommon, 500
# Solid Strider, 6, uncommon, 500
# Stealth, 6, uncommon, 500
# First Downer, 6, uncommon, 500
# Golden Pigskin, 6, uncommon, 500
# Tree Splitter, 6, uncommon, 500
# Crackshot, 5, legendary, 2000
# Flytrap, 5, legendary, 2000
# P.A.N.D.A Team Leader, 5, legendary, 2000
# Valkyrie, 5, legendary, 2000
# Aerobic Assassin, 5, epic, 1500
# Alpine Ace, 5, epic, 1500
# Alpine Ace (CAN), 5, epic, 1500
# Alpine Ace (CHN), 5, epic, 1500
# Alpine Ace (FRA), 5, epic, 1500
# Alpine Ace (GBR), 5, epic, 1500
# Alpine Ace (GER), 5, epic, 1500
# Alpine Ace (KOR), 5, epic, 1500
# Alpine Ace (USA), 5, epic, 1500
# Field Surgeon, 5, epic, 1500
# Flapjackie, 5, epic, 1500
# Growler, 5, epic, 1500
# Gumshoe, 5, epic, 1500
# Nara, 5, epic, 1500
# Sanctum, 5, epic, 1500
# Sleuth, 5, epic, 1500
# Sun Tan Specialist, 5, epic, 1500
# Taro, 5, epic, 1500
# Airlift, 5, epic, 1200
# Crypt Cruiser, 5, epic, 1200
# Cyclone, 5, epic, 1200
# Junkjet, 5, epic, 1200
# Shadow Puppet, 5, epic, 1200
# Venus Flyer, 5, epic, 1200
# Moonrise, 5, epic, 1200
# Party Animal, 5, epic, 1500
# Skull Sickle, 5, epic, 1200
# Drop The Bass, 5, epic, 800
# Hula, 5, epic, 800
# Phone It In, 5, epic, 800
# Shake It Up, 5, epic, 800
# Vivacious, 5, epic, 800
# Maki Master, 5, rare, 1200
# Mayhem, 5, rare, 1200
# Ruckus, 5, rare, 1200
# Skull Ranger, 5, rare, 1200
# Half Shell, 5, rare, 800
# Poofy Parasail, 5, rare, 800
# Snowblades, 5, rare, 800
# Airfoil, 5, rare, 800
# Clutch Axe, 5, rare, 800
# Reaper, 5, rare, 800
# Rescue Paddle, 5, rare, 800
# Tat Axe, 5, rare, 800
# Tendril, 5, rare, 800
# Capoeira, 5, rare, 500
# Criss Cross, 5, rare, 500
# Hootenanny, 5, rare, 500
# Rawr, 5, rare, 500
# Rocket Spinner, 5, rare, 500
# Sprinkler, 5, rare, 500
# Bullseye, 5, uncommon, 800
# Fossil Flyer, 5, uncommon, 500
# Rhinestone Rider, 5, uncommon, 500
# Storm Sigil, 5, uncommon, 500
# Tusk, 5, uncommon, 500
# Wasp, 5, uncommon, 500
# Gatekeeper, 5, uncommon, 500
# Jackspammer, 5, uncommon, 500
# Battle Call, 5, uncommon, 200
# Face Palm, 5, uncommon, 200
# True Love, 5, uncommon, 200
# Deadfire, 4, legendary, 2000
# Hot Ride, 4, legendary, 1500
# Castor, 4, epic, 1500
# Elmira, 4, epic, 1500
# Fyra, 4, epic, 1500
# Ghoul Trooper, 4, epic, 1500
# Hacivat, 4, epic, 1500
# Hollowhead, 4, epic, 1500
# Jack Gourdon, 4, epic, 1500
# Lace, 4, epic, 1500
# Mullet Marauder, 4, epic, 1500
# Paradox, 4, epic, 1500
# Slushy Soldier, 4, epic, 1500
# Snowfoot, 4, epic, 1500
# Snowstrike, 4, epic, 1500
# Synth Star, 4, epic, 1500
# Tender Defender, 4, epic, 1500
# Triage Trooper, 4, epic, 1500
# Coaxial Copter, 4, epic, 1200
# Dirigible, 4, epic, 1200
# Dark Shard, 4, epic, 1200
# Disco Brawl, 4, epic, 1500
# Glowsticks, 4, epic, 800
# Llamacadabra, 4, epic, 800
# Rocket Rodeo, 4, epic, 800
# Backbone, 4, rare, 1200
# Codename E.L.F., 4, rare, 1200
# Insight, 4, rare, 1200
# Longshot, 4, rare, 1200
# Maven, 4, rare, 1200
# Volley Girl, 4, rare, 1200
# Paper Plane, 4, rare, 800
# Tie-dye Flyer, 4, rare, 800
# Carrot Stick, 4, rare, 800
# Carver, 4, rare, 800
# Director's Cut, 4, rare, 800
# Flatliner, 4, rare, 800
# Ice Pop, 4, rare, 800
# Piledriver, 4, rare, 800
# Splinterstrike, 4, rare, 800
# Vision, 4, rare, 800
# Baller, 4, rare, 500
# Boneless, 4, rare, 500
# Busy, 4, rare, 500
# Dab, 4, rare, 500
# Headbanger, 4, rare, 500
# Step it Up, 4, rare, 500
# Tai Chi, 4, rare, 500
# Brainiac, 4, uncommon, 800
# Sgt. Green Clover, 4, uncommon, 800
# Equilibrium, 4, uncommon, 500
# Gingersled, 4, uncommon, 500
# Meltdown, 4, uncommon, 500
# Roadtrip, 4, uncommon, 500
# Touchdown, 4, uncommon, 500
# Triumph, 4, uncommon, 500
# Axercise, 4, uncommon, 500
# Clean Cut, 4, uncommon, 500
# Cookie Cutter, 4, uncommon, 500
# Crossroads, 4, uncommon, 500
# Lead Swinger, 4, uncommon, 500
# Scrambler, 4, uncommon, 500
# T-Square, 4, uncommon, 500
# Behold!, 4, uncommon, 200
# Breaking Point, 4, uncommon, 200
# Finger Wag, 4, uncommon, 200
# Hot Stuff, 4, uncommon, 200
# Howl, 4, uncommon, 200
# Job Well Done, 4, uncommon, 200
# Red Card, 4, uncommon, 200
# Rock Paper Scissors, 4, uncommon, 200
# Ark, 3, legendary, 2000
# DJ Bop, 3, legendary, 2000
# The Ice Queen, 3, legendary, 2000
# Cloaked Shadow, 3, epic, 1500
# Crackabella, 3, epic, 1500
# Dreamflower, 3, epic, 1500
# Far Out Man, 3, epic, 1500
# Fireworks Team Leader, 3, epic, 1500
# Guan Yu, 3, epic, 1500
# Hay Man, 3, epic, 1500
# Heidi, 3, epic, 1500
# Jaeger, 3, epic, 1500
# Kenji, 3, epic, 1500
# Kuno, 3, epic, 1500
# Lil Whip, 3, epic, 1500
# Ludwig, 3, epic, 1500
# Malcore, 3, epic, 1500
# Marshmello, 3, epic, 1500
# Mothmando, 3, epic, 1500
# Stage Slayer, 3, epic, 1500
# Straw Ops, 3, epic, 1500
# Yee-Haw!, 3, epic, 1500
# Choppa, 3, epic, 1200
# Divine Dragon, 3, epic, 1200
# Field Wraith, 3, epic, 1200
# Planetary Probe, 3, epic, 1200
# Candy Axe, 3, epic, 1500
# Evil Eye, 3, epic, 1200
# Global Axe, 3, epic, 1200
# Cheer Up, 3, epic, 800
# Magma, 3, epic, 700
# Cold Hearted (BUNDLE), 3, rare, 1000
# Bandolette, 3, rare, 1200
# Buccaneer, 3, rare, 1200
# Disco Diva, 3, rare, 1200
# Firewalker, 3, rare, 1200
# Fishstick, 3, rare, 1200
# Jumpshot, 3, rare, 1200
# Mezmer, 3, rare, 1200
# Recon Expert, 3, rare, 1200
# Riot, 3, rare, 1200
# Sea Wolf, 3, rare, 1200
# Skully, 3, rare, 1200
# Sunbird, 3, rare, 1200
# Triple Threat, 3, rare, 1200
# Coral Cruiser, 3, rare, 800
# Cozy Coaster, 3, rare, 800
# Diverge, 3, rare, 800
# Flutterbug, 3, rare, 800
# Heartspan, 3, rare, 0
# Oktoberfeast, 3, rare, 800
# Sunrise, 3, rare, 800
# Voyager, 3, rare, 800
# A.X.E., 3, rare, 800
# Battle Axe, 3, rare, 800
# Close Shave, 3, rare, 800
# Guandao, 3, rare, 800
# Harvester, 3, rare, 800
# High Seas, 3, rare, 800
# Icebringer, 3, rare, 800
# Outburst, 3, rare, 800
# Skully Splitter, 3, rare, 800
# Snow Globe, 3, rare, 800
# Throttle, 3, rare, 800
# Turbine, 3, rare, 800
# Virtue, 3, rare, 800
# Accolades, 3, rare, 500
# Backstroke, 3, rare, 500
# Clean Groove, 3, rare, 500
# Crazy Feet, 3, rare, 500
# Lazy Shuffle, 3, rare, 500
# Marsh Walk, 3, rare, 500
# Praise The Tomato, 3, rare, 500
# Showstopper, 3, rare, 500
# Slick, 3, rare, 500
# Something Stinks, 3, rare, 500
# Wild Card Wraps (BUNDLE), 3, uncommon, 600
# Bunnymoon, 3, uncommon, 800
# Cabbie, 3, uncommon, 800
# Patch Patroller, 3, uncommon, 800
# Red-nosed Ranger, 3, uncommon, 800
# Verge, 3, uncommon, 800
# Buckled, 3, uncommon, 800
# Blaze, 3, uncommon, 500
# Hyper, 3, uncommon, 500
# Mello Rider, 3, uncommon, 500
# Raptor, 3, uncommon, 500
# Windbreaker, 3, uncommon, 500
# Armature, 3, uncommon, 500
# Axcordion, 3, uncommon, 500
# Axetec, 3, uncommon, 800
# Bootstraps, 3, uncommon, 500
# Drumbeat, 3, uncommon, 500
# Fresh Cut, 3, uncommon, 500
# Lamp, 3, uncommon, 500
# Machete, 3, uncommon, 500
# Quickstrike, 3, uncommon, 500
# Air Horn, 3, uncommon, 200
# Breezy, 3, uncommon, 200
# Bring It, 3, uncommon, 200
# Click!, 3, uncommon, 200
# Denied, 3, uncommon, 200
# Dip, 3, uncommon, 200
# Gun Show, 3, uncommon, 200
# IDK, 3, uncommon, 200
# Shaolin Sit-up, 3, uncommon, 200
# Sparkler, 3, uncommon, 200
# Take 14, 3, uncommon, 200
# Candy Cane, 3, uncommon, 300
# Chromatic, 3, uncommon, 300
# Glimmer, 2, legendary, 2000
# Krampus, 2, legendary, 2000
# Malice, 2, legendary, 2000
# Beastmode, 2, epic, 1500
# Dante, 2, epic, 1500
# Deep Sea Destroyer, 2, epic, 1500
# Deep Sea Dominator, 2, epic, 1500
# Kitbash, 2, epic, 1500
# Lucky Rider, 2, epic, 1500
# Mogul Master, 2, epic, 1500
# Mogul Master (CAN), 2, epic, 1500
# Mogul Master (CHN), 2, epic, 1500
# Mogul Master (FRA), 2, epic, 1500
# Mogul Master (GBR), 2, epic, 1500
# Mogul Master (GER), 2, epic, 1500
# Mogul Master (KOR), 2, epic, 1500
# Mogul Master (USA), 2, epic, 1500
# Nightwitch, 2, epic, 1500
# Rebel, 2, epic, 1500
# Revolt, 2, epic, 1500
# Rosa, 2, epic, 1500
# Shaman, 2, epic, 1500
# Spooky Team Leader, 2, epic, 1500
# Sugarplum, 2, epic, 1500
# Bear Force One, 2, epic, 1500
# Coaxial  Copter, 2, epic, 1200
# Extra Cheese, 2, epic, 1200
# Krampus' Little Helper, 2, epic, 1200
# Nautilus, 2, epic, 1200
# Spirit, 2, epic, 1200
# Burning Axe, 2, epic, 1200
# Mauler, 2, epic, 1200
# Pot O' Gold, 2, epic, 1200
# Six String Striker, 2, epic, 1200
# Fire Spinner, 2, epic, 800
# Axiom, 2, rare, 1200
# Bendie, 2, rare, 1200
# Fastball, 2, rare, 1200
# Heartbreaker, 2, rare, 1200
# Hypernova, 2, rare, 1200
# Instinct, 2, rare, 1200
# Marino, 2, rare, 1200
# Psion, 2, rare, 1200
# Reflex, 2, rare, 1200
# Slugger, 2, rare, 1200
# Sparkplug, 2, rare, 1200
# Tech Ops, 2, rare, 1200
# Twistie, 2, rare, 1200
# Wingtip, 2, rare, 1200
# Crystal Carriage, 2, rare, 800
# Disruptor, 2, rare, 800
# Fuel, 2, rare, 800
# Ice Cream Cruiser, 2, rare, 800
# Pivot, 2, rare, 800
# Brat Catcher, 2, rare, 800
# Cuddle Paw, 2, rare, 800
# Emerald Smasher, 2, rare, 800
# Flimsie Flail, 2, rare, 800
# Flurry, 2, rare, 800
# Gold Digger, 2, rare, 800
# Moonbone, 2, rare, 800
# Night Slicer, 2, rare, 800
# Psionic Edge, 2, rare, 800
# Ski Boot, 2, rare, 800
# Spiky, 2, rare, 800
# Squid Striker, 2, rare, 800
# Tri-Star, 2, rare, 800
# Bobbin', 2, rare, 500
# Bombastic, 2, rare, 500
# Confused, 2, rare, 500
# Drum Major, 2, rare, 500
# Fandangle, 2, rare, 500
# Flux, 2, rare, 500
# Hitchhiker, 2, rare, 500
# Hot Marat, 2, rare, 0
# Jugglin', 2, rare, 500
# Kiss Kiss, 2, rare, 500
# Knee Slapper, 2, rare, 500
# Mime Time, 2, rare, 500
# On the Hook, 2, rare, 500
# Overdrive, 2, rare, 500
# Raining Doubloons, 2, rare, 500
# Spike It, 2, rare, 500
# Spring-Loaded, 2, rare, 500
# Spyglass, 2, rare, 500
# Treat Yourself, 2, rare, 500
# Whirlwind, 2, rare, 500
# Munitions Major, 2, uncommon, 800
# Star-Spangled Ranger, 2, uncommon, 800
# Star-Spangled Trooper, 2, uncommon, 800
# Sunflower, 2, uncommon, 800
# Tinseltoes, 2, uncommon, 800
# Lucky Coins, 2, uncommon, 200
# Sun Sprout, 2, uncommon, 200
# Fighter Kite, 2, uncommon, 500
# Home Run, 2, uncommon, 500
# Angular Axe, 2, uncommon, 500
# Chocollama, 2, uncommon, 500
# Grand Slammer, 2, uncommon, 500
# Krakenaxe, 2, uncommon, 500
# You Shouldn't Have!, 2, uncommon, 500
# Brush Your Shoulders, 2, uncommon, 200
# Finger Guns, 2, uncommon, 200
# Fist Pump, 2, uncommon, 200
# Go! Go! Go!, 2, uncommon, 200
# Ground Pound, 2, uncommon, 200
# Mind Blown, 2, uncommon, 200
# My Idol!, 2, uncommon, 200
# Scorecard, 2, uncommon, 200
# Shadow Boxer, 2, uncommon, 200
# Snap, 2, uncommon, 200
# Hot & Cold, 2, uncommon, 300
# Rivet, 2, uncommon, 300
# Leviathan (BUNDLE), 1, legendary, 3740
# Rex (BUNDLE), 1, legendary, 3740
# Wukong (BUNDLE), 1, legendary, 4080
# Dark Voyager, 1, legendary, 800
# Falcon, 1, legendary, 1500
# Funk Ops (BUNDLE), 1, epic, 3040
# Rogue Agent, 1, epic, 1500
# Trailblazer, 1, epic, 0
# Brite Blimp, 1, epic, 1200
# Hang Time, 1, epic, 1200
# Demon Skull, 1, epic, 1200
# Crackdown, 1, epic, 800
# Daydream, 1, epic, 800
# Empress, 1, epic, 1000
# Cloudbreaker, 1, rare, 1200
# Grimbles, 1, rare, 1200
# Cuddle Cruiser, 1, rare, 800
# Cold Snap, 1, rare, 800
# Peely Pick, 1, rare, 800
# Prickly Axe, 1, rare, 800
# Relax Axe, 1, rare, 800
# Slam Dunk, 1, rare, 800
# Star Wand, 1, rare, 800
# Stumpy, 1, rare, 800
# Chicken, 1, rare, 500
# Dream Feet, 1, rare, 500
# Flapper, 1, rare, 500
# Jamboree, 1, rare, 500
# Slap Happy, 1, rare, 500
# Switchstep, 1, rare, 500
# Golden Clouds, 1, rare, 600
# Pigskin, 1, rare, 0
# Birdie, 1, uncommon, 800
# Hayseed, 1, uncommon, 800
# Prickly Patroller, 1, uncommon, 800
# Haystacks, 1, uncommon, 200
# Targeted, 1, uncommon, 500
# Brute Force, 1, uncommon, 500
# Driver, 1, uncommon, 500
# Jazz Hands, 1, uncommon, 200
# Punched Up, 1, uncommon, 200
# Thumbs Down, 1, uncommon, 200
# Thumbs Up, 1, uncommon, 200
# Time Out, 1, uncommon, 200
# Unwrapped, 1, uncommon, 200
# Bandage, 1, uncommon, 300
# Digital Grayscale, 1, uncommon, 300
# Hot Cold, 1, uncommon, 300
# Lucky, 1, uncommon, 300
# Sprinkles, 1, uncommon, 300
# A.I.M., 0, legendary, 0
# Black Knight, 0, legendary, 0
# Blackheart, 0, legendary, 0
# Calamity, 0, legendary, 0
# Carbide, 0, legendary, 0
# Dire, 0, legendary, 0
# Drift, 0, legendary, 0
# Enforcer, 0, legendary, 0
# Eon, 0, legendary, 0
# Fallen Love Ranger, 0, legendary, 0
# Frostbite, 0, legendary, 0
# Frozen Love Ranger, 0, legendary, 0
# Frozen Raven, 0, legendary, 0
# Frozen Red Knight, 0, legendary, 0
# Havoc, 0, legendary, 0
# Hybrid, 0, legendary, 0
# Inferno, 0, legendary, 0
# Luxe, 0, legendary, 0
# Lynx, 0, legendary, 0
# Molten Battle Hound, 0, legendary, 0
# Molten Valkyrie, 0, legendary, 0
# Omega, 0, legendary, 0
# Ragnarok, 0, legendary, 0
# Rose Team Leader, 0, legendary, 0
# The Ice King, 0, legendary, 0
# The Prisoner, 0, legendary, 0
# The Reaper, 0, legendary, 0
# The Visitor, 0, legendary, 0
# Valor, 0, legendary, 0
# Warpaint, 0, legendary, 0
# Zenith, 0, legendary, 0
# Altitude, 0, legendary, 0
# Ark Wings, 0, legendary, 0
# Backup Plan, 0, legendary, 0
# Bamboo, 0, legendary, 0
# Battle Shroud, 0, legendary, 0
# Black Shield, 0, legendary, 0
# Bladed Wings, 0, legendary, 0
# Brat Bag, 0, legendary, 0
# Crested Cape, 0, legendary, 0
# Cuddle Bow, 0, legendary, 0
# Cuff Case, 0, legendary, 0
# Dark Matter, 0, legendary, 0
# Dark Void, 0, legendary, 0
# Dark Wings, 0, legendary, 0
# Deflector, 0, legendary, 0
# Destabilizer, 0, legendary, 0
# Dying Light, 0, legendary, 0
# E.L.I.M., 0, legendary, 0
# Enduring Cape, 0, legendary, 0
# Fallen Wings, 0, legendary, 0
# Fish Tank, 0, legendary, 0
# Freezing Point, 0, legendary, 0
# Frozen Iron Cage, 0, legendary, 0
# Frozen Love Wings, 0, legendary, 0
# Frozen Red Shield, 0, legendary, 0
# Frozen Shroud, 0, legendary, 0
# Glimmering Cloak, 0, legendary, 0
# Glow Show, 0, legendary, 0
# Hatchling, 0, legendary, 1200
# High Caliber, 0, legendary, 0
# Ice Mantle, 0, legendary, 0
# Ice Spikes, 0, legendary, 0
# Iron Cage, 0, legendary, 0
# Last Gasp, 0, legendary, 0
# Long Legs, 0, legendary, 0
# Love Wings, 0, legendary, 0
# Mertank, 0, legendary, 0
# Molten Crested Cape, 0, legendary, 0
# Molten Valkyrie Wings, 0, legendary, 0
# Mutiny, 0, legendary, 0
# Offworld Rig, 0, legendary, 0
# Ominous Orb, 0, legendary, 0
# Padlock, 0, legendary, 0
# Pursuit, 0, legendary, 0
# Raptor Satchel, 0, legendary, 0
# Red Shield, 0, legendary, 0
# Royale Flags, 0, legendary, 0
# Sashimono, 0, legendary, 0
# Scaly, 0, legendary, 0
# Shackled Stone, 0, legendary, 0
# Shark Fin, 0, legendary, 0
# Shiro, 0, legendary, 0
# Six String, 0, legendary, 0
# Skirmish, 0, legendary, 0
# Spider Shield, 0, legendary, 0
# Stabilizer, 0, legendary, 0
# Subjugator, 0, legendary, 0
# Valkyrie Wings, 0, legendary, 0
# Wolfpack, 0, legendary, 0
# Lavawing, 0, legendary, 0
# Highland Warrior (BUNDLE), 0, epic, 0
# Battlehawk, 0, epic, 0
# Blue Striker, 0, epic, 0
# Cobalt, 0, epic, 0
# DJ Yonder, 0, epic, 0
# Double Helix, 0, epic, 0
# Dusk, 0, epic, 0
# Elite Agent, 0, epic, 0
# Ember, 0, epic, 0
# Fable, 0, epic, 0
# Galaxy, 0, epic, 0
# Giddy-Up, 0, epic, 0
# Honor Guard, 0, epic, 0
# Huntress, 0, epic, 0
# IKONIK, 0, epic, 0
# Master Key, 0, epic, 0
# Mission Specialist, 0, epic, 0
# Moonwalker, 0, epic, 0
# Nightshade, 0, epic, 0
# Onesie, 0, epic, 0
# Peely, 0, epic, 0
# Powder, 0, epic, 0
# Redline, 0, epic, 0
# Rook, 0, epic, 0
# Royale Bomber, 0, epic, 0
# Rust Lord, 0, epic, 0
# Sgt. Winter, 0, epic, 0
# Sidewinder, 0, epic, 0
# Sledgehammer, 0, epic, 0
# Sparkle Specialist, 0, epic, 0
# Squad Leader, 0, epic, 0
# Sub Commander, 0, epic, 0
# Summit Striker, 0, epic, 0
# Sun Strider, 0, epic, 0
# Teknique, 0, epic, 0
# The Ace, 0, epic, 0
# Trog, 0, epic, 0
# Wingman, 0, epic, 0
# Zoey, 0, epic, 0
# Air Tank, 0, epic, 0
# Alpine Accessories, 0, epic, 0
# Arcanum, 0, epic, 0
# Astro, 0, epic, 0
# Back Plate, 0, epic, 0
# Ballistic, 0, epic, 0
# Balloon Llama, 0, epic, 0
# Bat Attitude, 0, epic, 0
# Battle Balloon, 0, epic, 0
# Birdhovel, 0, epic, 0
# Blasting Cap, 0, epic, 0
# Blue Shift, 0, epic, 0
# Board Bag, 0, epic, 0
# Bogey Bag, 0, epic, 0
# Boombox, 0, epic, 0
# Brite Bag, 0, epic, 0
# Buckler, 0, epic, 0
# Burgle Bag, 0, epic, 0
# Calavera, 0, epic, 0
# Cannister Carrier, 0, epic, 0
# Care Package, 0, epic, 0
# Catalyst, 0, epic, 0
# Clockworks, 0, epic, 0
# Cluefinder, 0, epic, 0
# Confidential Case, 0, epic, 0
# Contagion, 0, epic, 0
# Coven Cape, 0, epic, 0
# Crafted Carrier, 0, epic, 0
# Cuddle Doll, 0, epic, 0
# Deep Fried, 0, epic, 0
# Dismal Cape, 0, epic, 0
# Diving Tank, 0, epic, 0
# Dusk Wings, 0, epic, 0
# Eggshell, 0, epic, 0
# Emblazoned Buckler, 0, epic, 0
# Eternal, 0, epic, 0
# Evidence Bag, 0, epic, 0
# Fabled Cape, 0, epic, 0
# Flutterfrost, 0, epic, 0
# Galactic Disc, 0, epic, 0
# Ghost Portal, 0, epic, 0
# Giddy Gunner, 0, epic, 0
# Goodie Bag, 0, epic, 0
# Goodie Gourd, 0, epic, 0
# Gurney Gear, 0, epic, 0
# Hard Boiled, 0, epic, 0
# Hatchback, 0, epic, 0
# Hay Nest, 0, epic, 0
# Hip Shakers, 0, epic, 0
# Ice Cube, 0, epic, 0
# Ignition, 0, epic, 0
# Keytar, 0, epic, 0
# Kick Drum, 0, epic, 0
# Lane Splitter, 0, epic, 0
# Loyal Shield, 0, epic, 0
# Malcore Wings, 0, epic, 0
# Master Portal, 0, epic, 0
# Mini Marauder, 0, epic, 0
# Mogul Ski Bag, 0, epic, 0
# Mogul Ski Bag (CAN), 0, epic, 0
# Mogul Ski Bag (CHN), 0, epic, 0
# Mogul Ski Bag (FRA), 0, epic, 0
# Mogul Ski Bag (GBR), 0, epic, 0
# Mogul Ski Bag (GER), 0, epic, 0
# Mogul Ski Bag (KOR), 0, epic, 0
# Mogul Ski Bag (USA), 0, epic, 0
# Mouldering Cloak, 0, epic, 0
# Nibbles, 0, epic, 0
# Night Cloak, 0, epic, 0
# Octotank, 0, epic, 0
# Paradigm, 0, epic, 0
# Pathogen, 0, epic, 0
# Perfect Present, 0, epic, 0
# Pool Party, 0, epic, 0
# Pretzel Protector, 0, epic, 0
# Rearguard, 0, epic, 0
# Rebreather, 0, epic, 0
# Reinforced Backplate, 0, epic, 0
# Rescue Ring, 0, epic, 0
# Runic Shield, 0, epic, 0
# Rust Bucket, 0, epic, 0
# Shadow Wings, 0, epic, 0
# Slushy Jr., 0, epic, 0
# Snackshot, 0, epic, 0
# Sno Cone, 0, epic, 0
# Snow Star, 0, epic, 0
# Snowbrand, 0, epic, 0
# Special Delivery, 0, epic, 0
# Spellbinder, 0, epic, 0
# Spirit Cape, 0, epic, 0
# Steelcast, 0, epic, 0
# Stitches, 0, epic, 0
# Strongbox, 0, epic, 0
# Summer Strummer, 0, epic, 0
# Swag Bag, 0, epic, 0
# Tag Bag, 0, epic, 0
# Telemetry, 0, epic, 0
# Tome Pouch, 0, epic, 0
# Top Notch, 0, epic, 0
# Trash Lid, 0, epic, 0
# True North, 0, epic, 0
# Trusty Tusks, 0, epic, 0
# Uplink, 0, epic, 0
# Ventura Cape, 0, epic, 0
# Venturion Cape, 0, epic, 0
# Waveform, 0, epic, 0
# White Fang, 0, epic, 0
# Wingback, 0, epic, 0
# Woofs, 0, epic, 0
# Aurora, 0, epic, 0
# Booty Buoy, 0, epic, 0
# Conquest, 0, epic, 0
# Dark Engine, 0, epic, 0
# Discovery, 0, epic, 0
# Get Down!, 0, epic, 0
# High Octane, 0, epic, 0
# Intrepid, 0, epic, 0
# Rickety Runner, 0, epic, 0
# Rotor, 0, epic, 0
# Slipstream, 0, epic, 0
# Splashdown, 0, epic, 0
# Swarm, 0, epic, 0
# Wings of Valor, 0, epic, 0
# AC/DC, 0, epic, 0
# Controller, 0, epic, 0
# Dragon's Claw, 0, epic, 0
# Eva, 0, epic, 0
# Flawless, 0, epic, 0
# Ice Scepter, 0, epic, 0
# Ice Sceptre, 0, epic, 0
# Onslaught, 0, epic, 0
# Permafrost, 0, epic, 0
# Raider's Revenge, 0, epic, 1500
# Reckoning , 0, epic, 0
# Resonator, 0, epic, 0
# Rift Edge, 0, epic, 0
# Scorcher, 0, epic, 0
# Scratchmark, 0, epic, 0
# Stellar Axe, 0, epic, 0
# Swag Masher, 0, epic, 0
# Trusty No. 2, 0, epic, 0
# Boogie Down, 0, epic, 0
# Breakdown, 0, epic, 0
# Flamenco, 0, epic, 0
# Free Flow, 0, epic, 0
# Freestylin', 0, epic, 0
# Groove Jam, 0, epic, 0
# Hoop Master, 0, epic, 0
# The Robot, 0, epic, 0
# Bonesy, 0, epic, 0
# Bonesy (Mocha), 0, epic, 0
# Bonesy (White), 0, epic, 0
# Camo, 0, epic, 0
# Dodger, 0, epic, 0
# Dodger (Black), 0, epic, 0
# Dodger (Camo), 0, epic, 0
# Hamirez, 0, epic, 0
# Hamirez (Brown), 0, epic, 0
# Hamirez (Pink), 0, epic, 0
# Merry Munchkin, 0, epic, 0
# Remus, 0, epic, 0
# Remus (Ice), 0, epic, 0
# Remus (Skull), 0, epic, 0
# Scales, 0, epic, 0
# Scales (Black), 0, epic, 0
# Scales (Pink), 0, epic, 0
# Woodsy, 0, epic, 0
# Woodsy (Gold), 0, epic, 0
# Woodsy (Pirate), 0, epic, 0
# Fancy Basketball, 0, epic, 0
# Fancy Beach Ball, 0, epic, 0
# Fancy Golf Ball, 0, epic, 0
# Fancy Tomato, 0, epic, 0
# Clovers (BUNDLE), 0, rare, 0
# Coral Chorus (BUNDLE), 0, rare, 0
# Flying Standard (BUNDLE), 0, rare, 0
# Hybrid (BUNDLE), 0, rare, 0
# Lava (BUNDLE), 0, rare, 0
# Phantasm (BUNDLE), 0, rare, 0
# Star Power (BUNDLE), 0, rare, 0
# Vines (BUNDLE), 0, rare, 0
# Aerial Assault Trooper, 0, rare, 800
# Blue Squire, 0, rare, 0
# Blue Team Leader, 0, rare, 0
# Carbon Commando, 0, rare, 0
# Laguna, 0, rare, 0
# Prodigy, 0, rare, 0
# Renegade Raider, 0, rare, 1200
# Royale Knight, 0, rare, 0
# Stealth Reflex, 0, rare, 0
# Airflow, 0, rare, 0
# Birthday Cake, 0, rare, 0
# Capacitor, 0, rare, 0
# Carbon Pack, 0, rare, 0
# Chef's Choice, 0, rare, 0
# Cobra, 0, rare, 0
# Dark Bag, 0, rare, 0
# Disco Ball, 0, rare, 0
# Hypnotic, 0, rare, 0
# Insignia, 0, rare, 0
# Lil' Kev, 0, rare, 0
# Luminous Lamp, 0, rare, 0
# Oscilloscope, 0, rare, 0
# Para-Provisions, 0, rare, 0
# Penguin, 0, rare, 0
# Precision, 0, rare, 0
# Puncture Pack, 0, rare, 0
# Reaction Tank, 0, rare, 0
# Response Unit, 0, rare, 0
# Road Flair, 0, rare, 0
# Road Ready, 0, rare, 0
# Royale Shield, 0, rare, 0
# Saltwater Satchel, 0, rare, 0
# Scope Satchel, 0, rare, 0
# Scrappy, 0, rare, 0
# Shrimpy, 0, rare, 0
# Sight Sling, 0, rare, 0
# Skully Satchel, 0, rare, 0
# Spike Chamber, 0, rare, 0
# Squire Shield, 0, rare, 0
# Standard Issue, 0, rare, 0
# Sun Wings, 0, rare, 0
# Sweetheart, 0, rare, 0
# Tabulator, 0, rare, 0
# Techie, 0, rare, 0
# Used Racket, 0, rare, 0
# Blue Streak, 0, rare, 0
# Covered Crusader, 0, rare, 0
# Equalizer, 0, rare, 0
# Flappy, 0, rare, 0
# Frozen Feathers, 0, rare, 0
# Glidurrr, 0, rare, 0
# Lockstep, 0, rare, 0
# Rainbow Rider, 0, rare, 0
# Sky Serpents, 0, rare, 0
# Sugar Crash, 0, rare, 0
# Tactical Sleigh, 0, rare, 0
# Winter's Thorn, 0, rare, 0
# Abominable Axe, 0, rare, 0
# Axecalibur, 0, rare, 0
# Balloon Axe, 0, rare, 0
# Chill-Axe, 0, rare, 0
# Cold Hearted, 0, rare, 0
# Crowbar, 0, rare, 0
# Dread, 0, rare, 0
# Frozen Axe, 0, rare, 0
# Frozen Beak, 0, rare, 0
# Gale Force, 0, rare, 0
# Guiding Glow, 0, rare, 0
# Instigator, 0, rare, 0
# Lockpick, 0, rare, 0
# Lollipopper, 0, rare, 0
# Longhorn, 0, rare, 0
# Lug Axe, 0, rare, 0
# Marshy Smasher, 0, rare, 0
# Pinpoint, 0, rare, 0
# Pointer, 0, rare, 0
# Positron, 0, rare, 0
# Power Grip, 0, rare, 0
# Pulse Axe, 0, rare, 0
# Sawtooth, 0, rare, 0
# Smash Up, 0, rare, 0
# Snakebite, 0, rare, 0
# Tenderizer, 0, rare, 0
# Uni-horn, 0, rare, 0
# Best Mates, 0, rare, 0
# Calculated, 0, rare, 0
# Cat Flip, 0, rare, 0
# Conga, 0, rare, 0
# Dragon Stance, 0, rare, 0
# Fanciful, 0, rare, 500
# Fierce, 0, rare, 0
# Floss, 0, rare, 0
# Get Funky, 0, rare, 0
# Hand Signals, 0, rare, 0
# Hype, 0, rare, 0
# It's Go Time!, 0, rare, 0
# Keep It Mello, 0, rare, 0
# Mic Drop, 0, rare, 0
# Nana Nana, 0, rare, 0
# Orange Justice, 0, rare, 0
# Point It Out, 0, rare, 0
# Popcorn, 0, rare, 0
# Ride the Pony, 0, rare, 0
# Running Man, 0, rare, 0
# Scenario, 0, rare, 0
# Shimmer, 0, rare, 0
# Slitherin', 0, rare, 0
# Snoozefest, 0, rare, 0
# Swipe It, 0, rare, 0
# Take The L, 0, rare, 0
# The Worm, 0, rare, 0
# You're Awesome, 0, rare, 0
# All-Star, 0, rare, 0
# Artifact, 0, rare, 0
# Ballistics, 0, rare, 0
# Bats!, 0, rare, 0
# Bubbles, 0, rare, 0
# Cash Flow, 0, rare, 0
# Dark Feathers, 0, rare, 0
# Embers, 0, rare, 0
# Exhaust, 0, rare, 0
# Fiber Optics, 0, rare, 0
# Fireflies, 0, rare, 0
# Flames, 0, rare, 0
# Glitch in the System, 0, rare, 0
# Glyphs, 0, rare, 0
# Hearts, 0, rare, 0
# Ice Crystals, 0, rare, 0
# Jack-O-Lantern, 0, rare, 0
# Lanterns, 0, rare, 0
# Lightning, 0, rare, 0
# Rainbow, 0, rare, 0
# Retro Sci-Fi, 0, rare, 0
# Runic, 0, rare, 0
# Shooting Star, 0, rare, 0
# Snowflakes, 0, rare, 0
# Spectral Essence, 0, rare, 0
# Spray Paint, 0, rare, 0
# String Lights, 0, rare, 0
# Swirls, 0, rare, 0
# TP, 0, rare, 0
# Ultramarine, 0, rare, 0
# Virulent Flames, 0, rare, 0
# Luxe, 0, rare, 0
# Arctic Camo, 0, rare, 0
# Carbon &amp; Gold, 0, rare, 0
# Cuddle Hearts, 0, rare, 0
# Disco, 0, rare, 0
# Dragon Scales, 0, rare, 0
# Driftwood, 0, rare, 0
# Durrr Burger, 0, rare, 0
# Festive Paper, 0, rare, 0
# Gemstone, 0, rare, 0
# Golden Scales, 0, rare, 500
# Heat, 0, rare, 0
# Indigo Ice, 0, rare, 0
# Sunprint, 0, rare, 0
# Tiger Stripes, 0, rare, 0
# Tropical Camo, 0, rare, 0
# Ultra Red, 0, rare, 0
# Basketball, 0, rare, 0
# Beach Ball, 0, rare, 0
# Fancy Burger, 0, rare, 0
# Golf Ball, 0, rare, 0
# Ice Puck, 0, rare, 0
# Snowball, 0, rare, 0
# Tomato, 0, rare, 0
# Arachnids (BUNDLE), 0, uncommon, 0
# Isle of Treasure (BUNDLE), 0, uncommon, 0
# Master Key (BUNDLE), 0, uncommon, 0
# Power Chord (BUNDLE), 0, uncommon, 0
# Scallywags (BUNDLE), 0, uncommon, 0
# Sgt. Green Clover (BUNDLE), 0, uncommon, 0
# Spray Collage (BUNDLE), 0, uncommon, 0
# The Ice Queen (BUNDLE), 0, uncommon, 0
# Tricera Ops (BUNDLE), 0, uncommon, 0
# Combat Wreath, 0, uncommon, 0
# Slashed, 0, uncommon, 800
# Vintage, 0, uncommon, 800
# Aerial Assault One, 0, uncommon, 500
# Carbon, 0, uncommon, 0
# Cinder, 0, uncommon, 0
# Cold Front, 0, uncommon, 0
# Crossfire, 0, uncommon, 0
# Cruiser, 0, uncommon, 0
# Downshift, 0, uncommon, 0
# Helium, 0, uncommon, 0
# Mako, 0, uncommon, 0
# Modern, 0, uncommon, 500
# Picnic, 0, uncommon, 0
# Plunder, 0, uncommon, 0
# Purrfect, 0, uncommon, 0
# Royale Air, 0, uncommon, 0
# Royale X, 0, uncommon, 0
# Rush, 0, uncommon, 0
# Sir Glider The Brave, 0, uncommon, 0
# Steadfast, 0, uncommon, 0
# Scrambler, 0, uncommon, 0
# Gentleman's Dab, 0, uncommon, 0
# Golf Clap, 0, uncommon, 0
# Hello Friend, 0, uncommon, 0
# Regal Wave, 0, uncommon, 0
# Respect, 0, uncommon, 0
# Salute, 0, uncommon, 0
# Storm Salutation, 0, uncommon, 0
# Take The Elf, 0, uncommon, 0
# Wave, 0, uncommon, 0
# Abstract, 0, uncommon, 0
# Arrow, 0, uncommon, 0
# Bag Of Coal, 0, uncommon, 0
# Baited, 0, uncommon, 0
# Bananas, 0, uncommon, 0
# Boogie, 0, uncommon, 0
# Brite Bomber, 0, uncommon, 0
# Cactus Maze, 0, uncommon, 0
# Calamity, 0, uncommon, 0
# Chalk Outline, 0, uncommon, 0
# Circle, 0, uncommon, 0
# Crazy Castle, 0, uncommon, 0
# Cuddle Team Hula, 0, uncommon, 0
# Dance Mat, 0, uncommon, 0
# Deadfire, 0, uncommon, 0
# Dire, 0, uncommon, 0
# Distinguished, 0, uncommon, 0
# DJ Yonder, 0, uncommon, 0
# Do It!, 0, uncommon, 0
# Drift, 0, uncommon, 0
# Durrr, 0, uncommon, 0
# EEE, 0, uncommon, 0
# Ember, 0, uncommon, 0
# Fake Door, 0, uncommon, 0
# Fallen Love Ranger, 0, uncommon, 0
# Game Over, 0, uncommon, 0
# GG Potion, 0, uncommon, 0
# GG Smiley, 0, uncommon, 0
# GG Snakes, 0, uncommon, 0
# GG Snowman, 0, uncommon, 0
# Good Vibes, 0, uncommon, 0
# Gremlins, 0, uncommon, 0
# Grumpy Tree, 0, uncommon, 0
# Happy Birthday, 0, uncommon, 0
# Hearts, 0, uncommon, 0
# Kab-Llama, 0, uncommon, 0
# Kiss, 0, uncommon, 0
# Laser Chomp, 0, uncommon, 0
# Llama De Muertos, 0, uncommon, 0
# Looted, 0, uncommon, 0
# Love Ranger, 0, uncommon, 0
# Lucha GG, 0, uncommon, 0
# Lynx, 0, uncommon, 0
# Manhole Cover, 0, uncommon, 0
# Mask, 0, uncommon, 0
# Melting Snowman, 0, uncommon, 0
# Meow Moon, 0, uncommon, 0
# Mermaid, 0, uncommon, 0
# Moth, 0, uncommon, 0
# Neon Cat, 0, uncommon, 0
# Norse Llama, 0, uncommon, 0
# Oni, 0, uncommon, 0
# Peeled, 0, uncommon, 0
# Pixel Ramirez, 0, uncommon, 0
# Pixel Raven, 0, uncommon, 0
# Pixels Royale, 0, uncommon, 0
# Plugged In, 0, uncommon, 0
# Porthole, 0, uncommon, 0
# Potato Aim, 0, uncommon, 0
# Rainbow, 0, uncommon, 0
# Raven, 0, uncommon, 0
# Royal Stroll, 0, uncommon, 0
# Salty, 0, uncommon, 0
# Season Level 100, 0, uncommon, 0
# Sgt. Winter, 0, uncommon, 0
# Shadow Ops, 0, uncommon, 0
# Skeleton Key, 0, uncommon, 0
# Skull & Beard, 0, uncommon, 0
# Skull & Beard, 0, uncommon, 0
# Skull &amp; Beard, 0, uncommon, 0
# Solo Showdown, 0, uncommon, 0
# Spiderweb, 0, uncommon, 0
# Strawberry Paws, 0, uncommon, 0
# Sushi, 0, uncommon, 0
# Teknique, 0, uncommon, 0
# The Brood, 0, uncommon, 0
# The End, 0, uncommon, 0
# Three Llamas, 0, uncommon, 0
# Trap Warning, 0, uncommon, 0
# Trog Drawings, 0, uncommon, 0
# Tunnel, 0, uncommon, 0
# Wallcrawler, 0, uncommon, 0
# Window, 0, uncommon, 0
# Woot Bonesy, 0, uncommon, 0
# X Mark, 0, uncommon, 0
# Yummy, 0, uncommon, 0
# Blue Metallic, 0, uncommon, 0
# Burnmark, 0, uncommon, 0
# Clubs, 0, uncommon, 0
# Diamonds, 0, uncommon, 0
# Hearts, 0, uncommon, 0
# Pineapple, 0, uncommon, 0
# Spades, 0, uncommon, 0
# Valentine, 0, uncommon, 0
# Palm Leaf (BUNDLE), 0, common, 0
# K-Pop, 0, common, 0
# Recruit 1, 0, common, 0
# Recruit 2, 0, common, 0
# Recruit 3, 0, common, 0
# Recruit 4, 0, common, 0
# Recruit 5, 0, common, 0
# Recruit 6, 0, common, 0
# Recruit 7, 0, common, 0
# Recruit 8, 0, common, 0
# Founder's Glider, 0, common, 0
# Glider, 0, common, 0
# Pickaxe, 0, common, 0
# Unknown, 0, common, 0
# Dance Moves, 0, common, 0
# Unknown, 0, common, 0
